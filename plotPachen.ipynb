# %%
import numpy as np

# %%
# %pylab inline
# %run notebooktools.py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.linspace(1.1,100,1000)
b = 1
c = 0
y = b*x/(c+np.log(x))
plot(x,y)
ticks_visual(gca())
grid_visual(gca())
xscale('log')
yscale('log')
plt.ylabel('V, V')
plt.xlabel('pd, Torr cm')
savefig('PashenExample.png',bbox_inches='tight',dpi=200)
